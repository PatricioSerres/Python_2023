# %% [markdown]
# Primero se importarán las herramientas que serán utilizadas para el análisis de datos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import funciones.paths as paths

# %% [markdown]
# **Archivo imágenes clasificadas**

# %% [markdown]
# Lo primero que haremos es obtener el Data Frame a partir del archivo de imágenes etiquetadas.

# %%
df = pd.read_csv(paths.DIR_ETIQUETAR)
df
# Out:
#                                                 Ruta      Descripcion
# 0  directorios_entrega/etiquetar_imagenes/landsca...            arbol  \
# 1  directorios_entrega/etiquetar_imagenes/tree-73...    paisaje arbol
# 2  directorios_entrega/etiquetar_imagenes/imagsas...        montanias
# 3  directorios_entrega/etiquetar_imagenes/dsasasa...          cascada
# 4  directorios_entrega/etiquetar_imagenes/blog_fo...            lagos
# 5  directorios_entrega/etiquetar_imagenes/playa-d...            playa
# 6  directorios_entrega/etiquetar_imagenes/descarg...   paisajenatural
# 7  directorios_entrega/etiquetar_imagenes/deposit...         cascadas
# 8  directorios_entrega/etiquetar_imagenes/photo-1...  montaniacolores
# 9  directorios_entrega/etiquetar_imagenes/zea7uxr...        minecraft
#
#     Resolucion  Tamanio  Tipo              Tags      nick          Hora
# 0   (640, 359)    96732  JPEG       arbol;lindo     messi  1.687154e+09
# 1  (1280, 797)   185491  JPEG       lindo;arbol     messi  1.687154e+09
# 2   (265, 190)    10758  JPEG     montania;lago     messi  1.687154e+09
# 3   (275, 183)     9098  JPEG   paisaje;natural  otamendi  1.687154e+09
# 4  (1024, 500)   209234  JPEG  gente;naturaleza  otamendi  1.687154e+09
# 5  (1280, 720)   101037  JPEG         mar;playa     lauta  1.687154e+09
# 6   (284, 177)     8947  JPEG       pasto;verde  garnacho  1.687154e+09
# 7   (600, 374)    84376  WEBP              agua  garnacho  1.687154e+09
# 8  (1000, 643)    70755  JPEG           colores      dibu  1.687154e+09
# 9   (640, 360)   436666   PNG           creeper     licha  1.687154e+09

# %% [markdown]
# -*Gráfico de torta que muestre los porcentajes según el tipo de imagen*

# %% [markdown]
# Creamos una serie con la información de los tipos de las imágenes.

# %%
serie_tipos = df.groupby(df['Tipo']).size()
serie_tipos
# Out:
# Tipo
# JPEG    8
# PNG     1
# WEBP    1
# dtype: int64

# %% [markdown]
# Creamos una lista de etiquetas en el que se muestra cada tipo de imagen utilizada

# %%
etiquetas = list(serie_tipos.index)
etiquetas
# Out:
# ['JPEG', 'PNG', 'WEBP']

# %% [markdown]
# Luego de obtener la serie realizamos el gráfico de torta que muestre los porcentajes según el tipo de imagen

# %%
plt.pie(serie_tipos, labels= etiquetas, autopct='%1.1f%%', shadow= True, startangle=120, labeldistance= 1.1)
plt.axis('equal')
plt.legend(etiquetas)
plt.title('Tipos de imágenes')
plt.show()

# %% [markdown]
# -*Calcular los valores máximos de ancho y de alto de las imágenes clasificada*

# %% [markdown]
# Creamos una Data Frame con la resolución de las imágenes, divididos por ancho y alto

# %%
df_resoluciones = df['Resolucion'].str.split(',', expand=True)
df_resoluciones.columns = ('Ancho', 'Alto')
df_resoluciones
# Out:
#    Ancho   Alto
# 0   (640   359)
# 1  (1280   797)
# 2   (265   190)
# 3   (275   183)
# 4  (1024   500)
# 5  (1280   720)
# 6   (284   177)
# 7   (600   374)
# 8  (1000   643)
# 9   (640   360)

# %% [markdown]
# Eliminamos los paréntesis de apertura y cierre en el Data Frame

# %%
df_resoluciones['Ancho'] = df_resoluciones['Ancho'].str[1:]
df_resoluciones['Alto'] = df_resoluciones['Alto'].str[:-1]
df_resoluciones
# Out:
#   Ancho  Alto
# 0   640   359
# 1  1280   797
# 2   265   190
# 3   275   183
# 4  1024   500
# 5  1280   720
# 6   284   177
# 7   600   374
# 8  1000   643
# 9   640   360

# %% [markdown]
# Pasamos el Data Frame a enteros y obtenemos los máximos

# %%
df_resoluciones['Ancho'] = df_resoluciones['Ancho'].astype(int)
df_resoluciones['Alto'] = df_resoluciones['Alto'].astype(int)
print(f'Máximo ancho: {df_resoluciones["Ancho"].max()} px \nMáximo alto: {df_resoluciones["Alto"].max()} px')
# Out:
# Máximo ancho: 1280 px
# Máximo alto: 797 px

# %% [markdown]
# -*Generar un gráfico de dispersión para visualizar la relación entre el ancho y el alto de las imágenes.*

# %% [markdown]
# Se asocia a la variable x los valores del ancho de las imágenes etiquetadas y a la variable y los valores del alto de las mismas

# %%
x = df_resoluciones['Ancho']
y = df_resoluciones['Alto']
fig, ax = plt.subplots()
ax.scatter(x, y, marker = ".")
plt.xlabel('Ancho')
plt.ylabel('Alto')
plt.show()

# %% [markdown]
# -*En base a la fecha de última actualización, cantidad de cambios realizados para cada día de la semana (posible gráfico de torta o barras).*

# %% [markdown]
# Se importa datetime y se crea una nueva columna en el Data Frame llamada Fecha

# %%
from datetime import datetime

df['Hora'] = round(df['Hora'])
df['Fecha'] = df['Hora'].apply(lambda x: datetime.fromtimestamp(x))
df
# Out:
#                                                 Ruta      Descripcion
# 0  directorios_entrega/etiquetar_imagenes/landsca...            arbol  \
# 1  directorios_entrega/etiquetar_imagenes/tree-73...    paisaje arbol
# 2  directorios_entrega/etiquetar_imagenes/imagsas...        montanias
# 3  directorios_entrega/etiquetar_imagenes/dsasasa...          cascada
# 4  directorios_entrega/etiquetar_imagenes/blog_fo...            lagos
# 5  directorios_entrega/etiquetar_imagenes/playa-d...            playa
# 6  directorios_entrega/etiquetar_imagenes/descarg...   paisajenatural
# 7  directorios_entrega/etiquetar_imagenes/deposit...         cascadas
# 8  directorios_entrega/etiquetar_imagenes/photo-1...  montaniacolores
# 9  directorios_entrega/etiquetar_imagenes/zea7uxr...        minecraft
#
#     Resolucion  Tamanio  Tipo              Tags      nick          Hora
# 0   (640, 359)    96732  JPEG       arbol;lindo     messi  1.687154e+09  \
# 1  (1280, 797)   185491  JPEG       lindo;arbol     messi  1.687154e+09
# 2   (265, 190)    10758  JPEG     montania;lago     messi  1.687154e+09
# 3   (275, 183)     9098  JPEG   paisaje;natural  otamendi  1.687154e+09
# 4  (1024, 500)   209234  JPEG  gente;naturaleza  otamendi  1.687154e+09
# 5  (1280, 720)   101037  JPEG         mar;playa     lauta  1.687154e+09
# 6   (284, 177)     8947  JPEG       pasto;verde  garnacho  1.687154e+09
# 7   (600, 374)    84376  WEBP              agua  garnacho  1.687154e+09
# 8  (1000, 643)    70755  JPEG           colores      dibu  1.687154e+09
# 9   (640, 360)   436666   PNG           creeper     licha  1.687154e+09
#
#                 Fecha
# 0 2023-06-19 02:55:27
# 1 2023-06-19 02:55:42
# 2 2023-06-19 02:55:53
# 3 2023-06-19 02:56:09
# 4 2023-06-19 02:56:29
# 5 2023-06-19 02:56:52
# 6 2023-06-19 02:57:33
# 7 2023-06-19 02:57:44
# 8 2023-06-19 02:58:22
# 9 2023-06-19 02:59:01

# %% [markdown]
# Se crea una columna para dia de la semana

# %%
df['Dia_semana'] = df['Fecha'].dt.day_name()
df
# Out:
#                                                 Ruta      Descripcion
# 0  directorios_entrega/etiquetar_imagenes/landsca...            arbol  \
# 1  directorios_entrega/etiquetar_imagenes/tree-73...    paisaje arbol
# 2  directorios_entrega/etiquetar_imagenes/imagsas...        montanias
# 3  directorios_entrega/etiquetar_imagenes/dsasasa...          cascada
# 4  directorios_entrega/etiquetar_imagenes/blog_fo...            lagos
# 5  directorios_entrega/etiquetar_imagenes/playa-d...            playa
# 6  directorios_entrega/etiquetar_imagenes/descarg...   paisajenatural
# 7  directorios_entrega/etiquetar_imagenes/deposit...         cascadas
# 8  directorios_entrega/etiquetar_imagenes/photo-1...  montaniacolores
# 9  directorios_entrega/etiquetar_imagenes/zea7uxr...        minecraft
#
#     Resolucion  Tamanio  Tipo              Tags      nick          Hora
# 0   (640, 359)    96732  JPEG       arbol;lindo     messi  1.687154e+09  \
# 1  (1280, 797)   185491  JPEG       lindo;arbol     messi  1.687154e+09
# 2   (265, 190)    10758  JPEG     montania;lago     messi  1.687154e+09
# 3   (275, 183)     9098  JPEG   paisaje;natural  otamendi  1.687154e+09
# 4  (1024, 500)   209234  JPEG  gente;naturaleza  otamendi  1.687154e+09
# 5  (1280, 720)   101037  JPEG         mar;playa     lauta  1.687154e+09
# 6   (284, 177)     8947  JPEG       pasto;verde  garnacho  1.687154e+09
# 7   (600, 374)    84376  WEBP              agua  garnacho  1.687154e+09
# 8  (1000, 643)    70755  JPEG           colores      dibu  1.687154e+09
# 9   (640, 360)   436666   PNG           creeper     licha  1.687154e+09
#
#                 Fecha Dia_semana
# 0 2023-06-19 02:55:27     Monday
# 1 2023-06-19 02:55:42     Monday
# 2 2023-06-19 02:55:53     Monday
# 3 2023-06-19 02:56:09     Monday
# 4 2023-06-19 02:56:29     Monday
# 5 2023-06-19 02:56:52     Monday
# 6 2023-06-19 02:57:33     Monday
# 7 2023-06-19 02:57:44     Monday
# 8 2023-06-19 02:58:22     Monday
# 9 2023-06-19 02:59:01     Monday

# %% [markdown]
# Se crea un gráfico de barras con los días de la semana en los que se realizó algún etiquetado de imagen

# %%
dias_semana = df["Dia_semana"].value_counts()
dias_semana.plot(kind="bar")
plt.xlabel('Dia de la semana')
plt.ylabel('Cantidad de imágenes etiquetadas')
plt.show()

# %% [markdown]
# -*Crear un gráfico de líneas para visualizar la evolución de la cantidad de actualizaciones a lo largo del tiempo.*

# %% [markdown]
# Creo una nueva columna en el Data Frame en la que solo aparezca el dia (año, mes, dia)

# %%
df['Dia'] = df['Fecha'].dt.date
df
# Out:
#                                                 Ruta      Descripcion
# 0  directorios_entrega/etiquetar_imagenes/landsca...            arbol  \
# 1  directorios_entrega/etiquetar_imagenes/tree-73...    paisaje arbol
# 2  directorios_entrega/etiquetar_imagenes/imagsas...        montanias
# 3  directorios_entrega/etiquetar_imagenes/dsasasa...          cascada
# 4  directorios_entrega/etiquetar_imagenes/blog_fo...            lagos
# 5  directorios_entrega/etiquetar_imagenes/playa-d...            playa
# 6  directorios_entrega/etiquetar_imagenes/descarg...   paisajenatural
# 7  directorios_entrega/etiquetar_imagenes/deposit...         cascadas
# 8  directorios_entrega/etiquetar_imagenes/photo-1...  montaniacolores
# 9  directorios_entrega/etiquetar_imagenes/zea7uxr...        minecraft
#
#     Resolucion  Tamanio  Tipo              Tags      nick          Hora
# 0   (640, 359)    96732  JPEG       arbol;lindo     messi  1.687154e+09  \
# 1  (1280, 797)   185491  JPEG       lindo;arbol     messi  1.687154e+09
# 2   (265, 190)    10758  JPEG     montania;lago     messi  1.687154e+09
# 3   (275, 183)     9098  JPEG   paisaje;natural  otamendi  1.687154e+09
# 4  (1024, 500)   209234  JPEG  gente;naturaleza  otamendi  1.687154e+09
# 5  (1280, 720)   101037  JPEG         mar;playa     lauta  1.687154e+09
# 6   (284, 177)     8947  JPEG       pasto;verde  garnacho  1.687154e+09
# 7   (600, 374)    84376  WEBP              agua  garnacho  1.687154e+09
# 8  (1000, 643)    70755  JPEG           colores      dibu  1.687154e+09
# 9   (640, 360)   436666   PNG           creeper     licha  1.687154e+09
#
#                 Fecha Dia_semana         Dia
# 0 2023-06-19 02:55:27     Monday  2023-06-19
# 1 2023-06-19 02:55:42     Monday  2023-06-19
# 2 2023-06-19 02:55:53     Monday  2023-06-19
# 3 2023-06-19 02:56:09     Monday  2023-06-19
# 4 2023-06-19 02:56:29     Monday  2023-06-19
# 5 2023-06-19 02:56:52     Monday  2023-06-19
# 6 2023-06-19 02:57:33     Monday  2023-06-19
# 7 2023-06-19 02:57:44     Monday  2023-06-19
# 8 2023-06-19 02:58:22     Monday  2023-06-19
# 9 2023-06-19 02:59:01     Monday  2023-06-19

# %% [markdown]
# Creo el grafico de lineas utilizando la columna creada anteriormente

# %%
dias = df['Dia'].value_counts()
valoresX = df['Dia'].value_counts()
valoresY = df['Dia'].unique()
fig, ax = plt.subplots()
ax.plot(valoresY, valoresX, marker = "o")
plt.xlabel('Dia')
plt.ylabel('Actualizaciones')
plt.show()

# %% [markdown]
# -*Con la lista de tags generar una nube de palabras*

# %% [markdown]
# Importo el modulo wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# Creo una copia del Data Frame para generar una nube de palabras

# %%
df_nube= df.copy()
df_nube['Tags'] = df['Tags'].str.split(';')
nube_tags = df_nube['Tags'].explode().unique()
text = str(nube_tags)
wordcloud = WordCloud(width = 300, height = 200, random_state=1, background_color='white', colormap='Set2', collocations=False, stopwords = STOPWORDS).generate(text)
plt.figure(figsize=(40, 30))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# -*Informar cuáles son los 3 tags más utilizados*

# %%
df2= df.copy()
df2['Tags'] = df['Tags'].str.split(';')
tags = df2['Tags'].explode()
df_tags = pd.DataFrame(data=tags)
contador_tags = df_tags.groupby(['Tags']).value_counts().sort_values(ascending= False).head(3)
df_hola = pd.DataFrame(data=contador_tags)
df_hola
# Out:
#        count
# Tags
# arbol      2
# lindo      2
# agua       1

# %% [markdown]
# -*Calcular el tamaño en bytes promedio de las imágenes actualizadas por cada perfil, incluir los perfiles que no hayan realizado actualizaciones.*

# %% [markdown]
# Primero creamos el Data Frame de los perfiles

# %%
df_perfiles = pd.read_json(paths.DIR_USER)
df_perfiles
# Out:
#      Nombre      nick  Edad     Genero                                   foto
# 0     messi     messi    36     Hombre     imagenes/avatares/avatar_messi.png
# 1  otamendi  otamendi    21     Hombre  imagenes/avatares/avatar_otamendi.png
# 2     lauta     lauta    23  nobinario     imagenes/avatares/avatar_lauta.png
# 3       ale  garnacho    19      Mujer  imagenes/avatares/avatar_garnacho.png
# 4      dibu      dibu    30     Hombre      imagenes/avatares/avatar_dibu.png
# 5     licha     licha    23     Hombre     imagenes/avatares/avatar_licha.png

# %% [markdown]
# Se hace un merge entre todos los perfiles y el archivo de etiquetar imágenes

# %%
outer_join = pd.merge(df, df_perfiles, on= 'nick', how= 'outer')
outer_join = outer_join.fillna(0)
outer_join
# Out:
#                                                 Ruta      Descripcion
# 0  directorios_entrega/etiquetar_imagenes/landsca...            arbol  \
# 1  directorios_entrega/etiquetar_imagenes/tree-73...    paisaje arbol
# 2  directorios_entrega/etiquetar_imagenes/imagsas...        montanias
# 3  directorios_entrega/etiquetar_imagenes/dsasasa...          cascada
# 4  directorios_entrega/etiquetar_imagenes/blog_fo...            lagos
# 5  directorios_entrega/etiquetar_imagenes/playa-d...            playa
# 6  directorios_entrega/etiquetar_imagenes/descarg...   paisajenatural
# 7  directorios_entrega/etiquetar_imagenes/deposit...         cascadas
# 8  directorios_entrega/etiquetar_imagenes/photo-1...  montaniacolores
# 9  directorios_entrega/etiquetar_imagenes/zea7uxr...        minecraft
#
#     Resolucion  Tamanio  Tipo              Tags      nick          Hora
# 0   (640, 359)    96732  JPEG       arbol;lindo     messi  1.687154e+09  \
# 1  (1280, 797)   185491  JPEG       lindo;arbol     messi  1.687154e+09
# 2   (265, 190)    10758  JPEG     montania;lago     messi  1.687154e+09
# 3   (275, 183)     9098  JPEG   paisaje;natural  otamendi  1.687154e+09
# 4  (1024, 500)   209234  JPEG  gente;naturaleza  otamendi  1.687154e+09
# 5  (1280, 720)   101037  JPEG         mar;playa     lauta  1.687154e+09
# 6   (284, 177)     8947  JPEG       pasto;verde  garnacho  1.687154e+09
# 7   (600, 374)    84376  WEBP              agua  garnacho  1.687154e+09
# 8  (1000, 643)    70755  JPEG           colores      dibu  1.687154e+09
# 9   (640, 360)   436666   PNG           creeper     licha  1.687154e+09
#
#                 Fecha Dia_semana         Dia    Nombre  Edad     Genero
# 0 2023-06-19 02:55:27     Monday  2023-06-19     messi    36     Hombre  \
# 1 2023-06-19 02:55:42     Monday  2023-06-19     messi    36     Hombre
# 2 2023-06-19 02:55:53     Monday  2023-06-19     messi    36     Hombre
# 3 2023-06-19 02:56:09     Monday  2023-06-19  otamendi    21     Hombre
# 4 2023-06-19 02:56:29     Monday  2023-06-19  otamendi    21     Hombre
# 5 2023-06-19 02:56:52     Monday  2023-06-19     lauta    23  nobinario
# 6 2023-06-19 02:57:33     Monday  2023-06-19       ale    19      Mujer
# 7 2023-06-19 02:57:44     Monday  2023-06-19       ale    19      Mujer
# 8 2023-06-19 02:58:22     Monday  2023-06-19      dibu    30     Hombre
# 9 2023-06-19 02:59:01     Monday  2023-06-19     licha    23     Hombre
#
#                                     foto
# 0     imagenes/avatares/avatar_messi.png
# 1     imagenes/avatares/avatar_messi.png
# 2     imagenes/avatares/avatar_messi.png
# 3  imagenes/avatares/avatar_otamendi.png
# 4  imagenes/avatares/avatar_otamendi.png
# 5     imagenes/avatares/avatar_lauta.png
# 6  imagenes/avatares/avatar_garnacho.png
# 7  imagenes/avatares/avatar_garnacho.png
# 8      imagenes/avatares/avatar_dibu.png
# 9     imagenes/avatares/avatar_licha.png

# %% [markdown]
# Agrupo por el Data Frame por nick y hago un promedio del tamaño

# %%
promedio_tamanio_por_nick = outer_join.groupby('nick')['Tamanio'].mean()
promedio_tamanio_por_nick
# Out:
# nick
# dibu         70755.000000
# garnacho     46661.500000
# lauta       101037.000000
# licha       436666.000000
# messi        97660.333333
# otamendi    109166.000000
# Name: Tamanio, dtype: float64

# %% [markdown]
# **Archivo log del sistema**

# %% [markdown]
# Primero abrimos el archivo de logs, pasamos el timestamp a una fecha legible y creamos la columna del dia de la semana.

# %%
ds = pd.read_csv(paths.DIR_LOGS, encoding='utf-8')
ds['timestamp'] = ds['timestamp'].apply(lambda x: datetime.fromtimestamp(x))
ds['Día'] = ds['timestamp'].dt.day_name()
ds
# Out:
#                     timestamp      nick                 operacion
# 0  2023-06-19 02:55:26.692382     messi  nueva_imagen_clasificada  \
# 1  2023-06-19 02:55:42.214125     messi  nueva_imagen_clasificada
# 2  2023-06-19 02:55:52.744954     messi  nueva_imagen_clasificada
# 3  2023-06-19 02:56:08.803888  otamendi  nueva_imagen_clasificada
# 4  2023-06-19 02:56:28.501054  otamendi  nueva_imagen_clasificada
# 5  2023-06-19 02:56:51.966797     lauta  nueva_imagen_clasificada
# 6  2023-06-19 02:57:11.807623  garnacho              nuevo_perfil
# 7  2023-06-19 02:57:33.193770  garnacho  nueva_imagen_clasificada
# 8  2023-06-19 02:57:44.426406  garnacho  nueva_imagen_clasificada
# 9  2023-06-19 02:58:05.262335      dibu              nuevo_perfil
# 10 2023-06-19 02:58:21.987438      dibu  nueva_imagen_clasificada
# 11 2023-06-19 02:58:46.745803     licha              nuevo_perfil
# 12 2023-06-19 02:59:01.178646     licha  nueva_imagen_clasificada
# 13 2023-06-19 02:59:46.433024     licha      cambio_configuracion
# 14 2023-06-19 02:59:51.301445     licha      cambio_configuracion
# 15 2023-06-19 03:00:04.993201     licha      cambio_configuracion
# 16 2023-06-19 03:00:10.701520     licha      cambio_configuracion
# 17 2023-06-19 03:00:15.575786     licha      cambio_configuracion
# 18 2023-06-19 03:00:25.848381     licha          modificar_perfil
# 19 2023-06-19 03:00:29.297509     licha          modificar_perfil
# 20 2023-06-19 03:00:32.184608     licha          modificar_perfil
# 21 2023-06-19 03:00:35.318711     licha          modificar_perfil
# 22 2023-06-19 03:00:38.270897     licha          modificar_perfil
# 23 2023-06-19 03:00:41.768606     licha          modificar_perfil
# 24 2023-06-19 03:00:44.803320     licha          modificar_perfil
# 25 2023-06-19 03:00:53.765910     licha          modificar_perfil
# 26 2023-06-19 03:00:59.948893     licha          modificar_perfil
# 27 2023-06-19 03:01:03.576383     licha          modificar_perfil
# 28 2023-06-19 03:01:07.211682     licha          modificar_perfil
# 29 2023-06-19 03:01:10.780661     licha          modificar_perfil
# 30 2023-06-19 03:01:15.278068     licha          modificar_perfil
# 31 2023-06-19 03:01:18.932109     licha          modificar_perfil
# 32 2023-06-19 03:01:22.392338     licha          modificar_perfil
# 33 2023-06-19 03:01:25.994282     licha          modificar_perfil
# 34 2023-06-19 03:01:28.896794     licha          modificar_perfil
# 35 2023-06-19 03:01:31.727802     licha          modificar_perfil
# 36 2023-06-19 03:01:36.928241     licha          modificar_perfil
# 37 2023-06-19 03:01:58.840900     licha                nuevo_meme
# 38 2023-06-19 03:02:35.671193     licha             nuevo collage
# 39 2023-06-19 03:02:41.072410     licha          modificar_perfil
# 40 2023-06-19 03:02:44.272339     licha          modificar_perfil
# 41 2023-06-19 03:02:46.873994     licha          modificar_perfil
# 42 2023-06-19 03:09:12.505444  otamendi             nuevo collage
# 43 2023-07-10 22:35:39.660238  otamendi             nuevo collage
# 44 2023-07-10 22:50:39.778902  otamendi             nuevo collage
# 45 2023-07-10 22:52:10.993547  otamendi             nuevo collage
#
#                                               valores              textos
# 0                                                 NaN                 NaN  \
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
# 24                                                NaN                 NaN
# 25                                                NaN                 NaN
# 26                                                NaN                 NaN
# 27                                                NaN                 NaN
# 28                                                NaN                 NaN
# 29                                                NaN                 NaN
# 30                                                NaN                 NaN
# 31                                                NaN                 NaN
# 32                                                NaN                 NaN
# 33                                                NaN                 NaN
# 34                                                NaN                 NaN
# 35                                                NaN                 NaN
# 36                                                NaN                 NaN
# 37                                  tres_dragones.jpg      hola;chau;hola
# 38  imagsasassasaes.jpg;playa-de-isuntza-lekeitio_...  ESTO ES UNA PRUEBA
# 39                                                NaN                 NaN
# 40                                                NaN                 NaN
# 41                                                NaN                 NaN
# 42           landscape-1192669_640.jpg;dsasasasfs.jpg       LINDO PAISAJE
# 43               imagsasassasaes.jpg;descarga (1).jpg            xxxxxxxx
# 44  blog_fotografia_de_paisajes_tips_y_consejos_1-...               aaaaa
# 45  dsasasasfs.jpg;playa-de-isuntza-lekeitio__1280...            aaaaaaaa
#
#        Día
# 0   Monday
# 1   Monday
# 2   Monday
# 3   Monday
# 4   Monday
# 5   Monday
# 6   Monday
# 7   Monday
# 8   Monday
# 9   Monday
# 10  Monday
# 11  Monday
# 12  Monday
# 13  Monday
# 14  Monday
# 15  Monday
# 16  Monday
# 17  Monday
# 18  Monday
# 19  Monday
# 20  Monday
# 21  Monday
# 22  Monday
# 23  Monday
# 24  Monday
# 25  Monday
# 26  Monday
# 27  Monday
# 28  Monday
# 29  Monday
# 30  Monday
# 31  Monday
# 32  Monday
# 33  Monday
# 34  Monday
# 35  Monday
# 36  Monday
# 37  Monday
# 38  Monday
# 39  Monday
# 40  Monday
# 41  Monday
# 42  Monday
# 43  Monday
# 44  Monday
# 45  Monday

# %% [markdown]
# -Realizar un gráfico comparando los días de la semana en que se realizaron

# %%
from matplotlib import pyplot as plt
dias = ds['Día'].value_counts().sort_values(ascending=False)
dias.plot(kind='bar')
dias
# Out:
# Día
# Monday    46
# Name: count, dtype: int64

# %% [markdown]
# Para hacer el gráfico de barra, creamos una nueva variable, que contenga el día de la semana y la cantidad de operaciones
# que se hicieron en este.

# %% [markdown]
# -Generar un gráfico que muestre los porcentajes de uso de la aplicación por género

# %%
js = pd.read_json(paths.DIR_USER)
js
# Out:
#      Nombre      nick  Edad     Genero                                   foto
# 0     messi     messi    36     Hombre     imagenes/avatares/avatar_messi.png
# 1  otamendi  otamendi    21     Hombre  imagenes/avatares/avatar_otamendi.png
# 2     lauta     lauta    23  nobinario     imagenes/avatares/avatar_lauta.png
# 3       ale  garnacho    19      Mujer  imagenes/avatares/avatar_garnacho.png
# 4      dibu      dibu    30     Hombre      imagenes/avatares/avatar_dibu.png
# 5     licha     licha    23     Hombre     imagenes/avatares/avatar_licha.png

# %% [markdown]
# Abrimos el json con pandas,contamos la cantidad de generos y hacemos una con cada uno de ellos.

# %%
generos = js['Genero'].value_counts().sort_values(ascending=False)
lista_generos = list(generos.index)
lista_generos
# Out:
# ['Hombre', 'nobinario', 'Mujer']

# %% [markdown]
# Luego hacemos una lista con la cantidad total de cada genero, y la mostramos en un gráfico de pastel.

# %%
aux = list(generos.values)

plt.pie(aux, labels=lista_generos, autopct='%1.1f%%', shadow=True, startangle=120)
plt.axis('equal')
plt.legend(lista_generos)
plt.show()

# %% [markdown]
# -Generar un gráfico que refleje las cantidades de cada operación realizada.

# %%
operaciones = ds['operacion'].value_counts().sort_values(ascending=False)
operaciones.plot(kind='bar')
operaciones
# Out:
# operacion
# modificar_perfil            22
# nueva_imagen_clasificada    10
# cambio_configuracion         5
# nuevo collage                5
# nuevo_perfil                 3
# nuevo_meme                   1
# Name: count, dtype: int64

# %% [markdown]
# Se realiza una operación similar a la antes vista. Para eso creamos una variable 'operacion', que contenga
# cuantas operaciones de cada una se realizaron y luego lo mostramos en el gráfico.

# %%
prueba = ds['nick'].value_counts().sort_values(ascending=False)
cuenta = list(ds['nick'].value_counts().sort_values(ascending=False))
nombres_ordenados = list(prueba.index)
plt.barh(nombres_ordenados, cuenta)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# -Generar un ranking de las 5 imágenes más usadas para generar memes y otro para
# generar collages.

# %% [markdown]
# En un Data frame se guardan aquellas filas donde la operacion sea "nuevo_meme". Luego se divide el valor de las imagenes y se las guarda en un nuevo dataframe. Finalmente, en la variable contador imagenes se agrupa por imagen, se cuenta cuantas veces aparece cada una, se ordena el dataframe y se toman los primeros 5 para mostrar

# %%
newds = ds.copy()
newds = newds[(newds['operacion'] == 'nuevo_meme')] 
newds['valores'] = newds['valores'].str.split(';')
imagenes = newds['valores'].explode()
ds_imagenes = pd.DataFrame(data=imagenes)
contador_imagenes = ds_imagenes.groupby(['valores']).value_counts().sort_values(ascending= False).head(5)
contador_imagenes
# Out:
# valores
# tres_dragones.jpg    1
# Name: count, dtype: int64

# %% [markdown]
# Lo mismo ocurre con las 5 imagenes mas usadas en la generación de collages

# %%
ds_coll = ds.copy()
ds_coll = ds_coll[(ds_coll['operacion'] == 'nuevo collage')] 
ds_coll['valores'] = ds_coll['valores'].str.split(';')
imagenes = ds_coll['valores'].explode()
ds_imagenes = pd.DataFrame(data=imagenes)
contador_imagenes = ds_imagenes.groupby(['valores']).value_counts().sort_values(ascending= False).head(5)
contador_imagenes
# Out:
# valores
# descarga (1).jpg                                                                 2
# dsasasasfs.jpg                                                                   2
# imagsasassasaes.jpg                                                              2
# playa-de-isuntza-lekeitio__1280x720.jpg                                          2
# blog_fotografia_de_paisajes_tips_y_consejos_1-fotografia-de-paisajes-lago.jpg    1
# Name: count, dtype: int64

# %% [markdown]
# -Generar una nube de palabras de los textos agregados en los collages y otra con los
# textos agregados en los memes

# %%
ds_nube_collage = ds[(ds['operacion'] == 'nuevo collage')]
ds_nube_collage
# Out:
#                     timestamp      nick      operacion
# 38 2023-06-19 03:02:35.671193     licha  nuevo collage  \
# 42 2023-06-19 03:09:12.505444  otamendi  nuevo collage
# 43 2023-07-10 22:35:39.660238  otamendi  nuevo collage
# 44 2023-07-10 22:50:39.778902  otamendi  nuevo collage
# 45 2023-07-10 22:52:10.993547  otamendi  nuevo collage
#
#                                               valores              textos
# 38  imagsasassasaes.jpg;playa-de-isuntza-lekeitio_...  ESTO ES UNA PRUEBA  \
# 42           landscape-1192669_640.jpg;dsasasasfs.jpg       LINDO PAISAJE
# 43               imagsasassasaes.jpg;descarga (1).jpg            xxxxxxxx
# 44  blog_fotografia_de_paisajes_tips_y_consejos_1-...               aaaaa
# 45  dsasasasfs.jpg;playa-de-isuntza-lekeitio__1280...            aaaaaaaa
#
#        Día
# 38  Monday
# 42  Monday
# 43  Monday
# 44  Monday
# 45  Monday

# %%
nube_tags = ds_nube_collage['textos'].explode().unique()
text = str(nube_tags)
wordcloud = WordCloud(width = 300, height = 200, random_state=1, background_color='white', colormap='Set2', collocations=False, stopwords = STOPWORDS).generate(text)
plt.figure(figsize=(40, 30))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
ds_nube_meme = ds[(ds['operacion'] == 'nuevo_meme')]
ds_nube_meme
# Out:
#                     timestamp   nick   operacion            valores
# 37 2023-06-19 03:01:58.840900  licha  nuevo_meme  tres_dragones.jpg  \
#
#             textos     Día
# 37  hola;chau;hola  Monday

# %%
nube_tags = ds_nube_meme['textos'].explode().unique()
text = str(nube_tags)
wordcloud = WordCloud(width = 300, height = 200, random_state=1, background_color='white', colormap='Set2', collocations=False, stopwords = STOPWORDS).generate(text)
plt.figure(figsize=(40, 30))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# - Con los datos del archivo de perfiles generar un gráfico de torta con los porcentajes
# según género de las personas que realizaron las operaciones:
#     ○ Nueva imagen clasificada.
#     ○ Modificación de imagen previamente clasificada.

# %% [markdown]
# Se realiza un merge entre el archivo de logs y el jason que contiene los perfiles. Luego deja en el dataframe solo aquellas lineas donde se haya clasificado una nueva imagen o se haya cambiado una anterior, y cuenta cuantas veces aparece cada genero

# %%
outer_join = pd.merge(ds, js, on= 'nick', how= 'outer')
outer_join = outer_join.fillna(0)
ds_t = outer_join[((outer_join['operacion'] == 'nueva_imagen_clasificada') | (outer_join['operacion'] == 'imagen_previamente_clasificada'))]
serie_genero = ds_t.groupby(['Genero']).size()
serie_genero
# Out:
# Genero
# Hombre       7
# Mujer        2
# nobinario    1
# dtype: int64

# %%
etiquetas = list(serie_genero.index)
plt.pie(serie_genero, labels= etiquetas, autopct='%1.1f%%', startangle=120, labeldistance= 1.1)
plt.axis('equal')
plt.legend(etiquetas)
plt.title('porcentajes según género de las personas que realizaron las operaciones: Nueva imagen clasificada o Modificación de imagen previamente clasificada.')
plt.show()
